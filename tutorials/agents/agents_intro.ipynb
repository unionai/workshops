# %% [markdown]
# # Buiding AI Agents with Union.ai

# %% [markdown]
# This tutorial demonstrates how to build AI agents using the Union.ai platform. We will cover the basics of setting up an agent, defining its capabilities, and integrating it with various data sources and APIs.
#
# Union.ai ... is
#
# See more Agent examples (here)[]
#
# ### Sections Covered:
# - Tool calling agent
# - Reflection & Planning
# - Parallel execution
# - Multi agent
# - Code execution in containers

# %% [markdown]
# ## Tool Calling Agent

# %%
# !flyte create secret

# %%
import flyte

# %%
env = flyte.TaskEnvironment(
    name="ai_agent_env",
    image=flyte.Image.from_debian_base().with_requirements("requirements.txt"),
    secrets=[
        flyte.Secret(key="OPENAI_API_KEY", as_env_var="OPENAI_API_KEY"),

    ]
)

# data models


# tools
